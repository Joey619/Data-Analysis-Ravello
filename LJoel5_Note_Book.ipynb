# %% [markdown]
# <a href="https://colab.research.google.com/github/Joey619/Data-Analysis-Ravello/blob/main/LJoel5_Note_Book.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset("iris")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.lineplot(x='sepal_length', y='sepal_width', data= data),
plt.title('Mr Ravello using Matplotlib Function')
# Out:
# Text(0.5, 1.0, 'Mr Ravello using Matplotlib Function')

# %%
data= sns.load_dataset('iris')

# %%
sns.pairplot(data=data, hue='species')
plt. title('Ravello Practice Designs')
# Out:
# Text(0.5, 1.0, 'Ravello Practice Designs')

# %% [markdown]
# Specialist in Data Analysis, Data Visualization, Azure Enterprise and Powerbi
#
# L J Ravello Consultancy
#
# Microsoft Certified Azure Enterprise Data Analysis.
#
# Microsoft Certified Power Bi Data Analysis and Excel Expert
