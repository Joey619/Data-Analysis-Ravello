# %% [markdown]
# # Analysing Tips Dataset

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt

# %%
df= sb.load_dataset ('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ##### To change the visual display replace scatterplot with lineplot, scatterplot, histplot

# %%
import pandas as pd

# %%
import seaborn as sb
from matplotlib import pyplot as plt

# %%
df= sns.load_dataset("tips")

# %%
sb.scatterplot(x='total_bill',y='tip', hue='sex', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Next Section

# %% [markdown]
# ### Exercise Data

# %%
df= sns.load_dataset("exercise")

# %%
df.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
sns.violinplot(x="time", y= "pulse", hue="kind",data=df),
plt.title("L.Ravello Designs")
# Out:
# Text(0.5, 1.0, 'L.Ravello Designs')

# %%
##### To change the visual display replace, violinplot with lineplot, scatterplot, histplot
